# %% [markdown]
# # **Basic implementation of Opus_mt_en_hi model to convert english text to hindi**

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 9.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 41.7 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 44.3 MB/s
# ...
#      |████████████████████████████████| 77 kB 9.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 1.2 MB 7.8 MB/s
# ...

# %% [markdown]
# # Loading the tokenizer and the model

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM


tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
# Out:
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/793k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.02M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/292M [00:00<?, ?B/s]

# %% [markdown]
# #This is a function to translate english text to hindi

# %%
def translator_eng_to_hin(text):
  
  input_ids = tokenizer.encode(text, return_tensors="pt", padding=True)
  outputs = model.generate(input_ids)
  decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
  
  return decoded_text

# %% [markdown]
# # Dummy text to translate

# %%
texts = ["My name is Ruchir and I live in Indore.",
        "He hasn't written to them in a long time.",
        "	Your dreams have come true.",
        "Thanks. I'll pay you back on Friday.",
        "Do we have anything I can snack on?"]

for text in texts:
  print("English Text: ", text)
  print("Hindi Translation: ", translator_eng_to_hin(text))
  print("-"*100,"\n")
# Out:
# English Text:  My name is Ruchir and I live in Indore.
# Hindi Translation:  मेरा नाम राउर है और मैं इंडोर में रहते हैं.
# ----------------------------------------------------------------------------------------------------
#
# English Text:  He hasn't written to them in a long time.
# Hindi Translation:  उन्होंने कहा कि एक लंबे समय में उन्हें लिखा नहीं है।
# ----------------------------------------------------------------------------------------------------
#
# English Text:  	Your dreams have come true.
# Hindi Translation:  तुम्हारे सपने सच हो गए हैं.
# ----------------------------------------------------------------------------------------------------
#
# English Text:  Thanks. I'll pay you back on Friday.
# Hindi Translation:  मैं शुक्रवार को आप वापस भुगतान करेंगे.
# ----------------------------------------------------------------------------------------------------
#
# English Text:  Do we have anything I can snack on?
# Hindi Translation:  हम कुछ भी मैं पर नाश्ता कर सकते हैं?
# ...
